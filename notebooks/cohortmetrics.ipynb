# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Dependencies" data-toc-modified-id="Dependencies-1">Dependencies</a></span></li><li><span><a href="#Functions" data-toc-modified-id="Functions-2">Functions</a></span></li><li><span><a href="#Paths" data-toc-modified-id="Paths-3">Paths</a></span></li><li><span><a href="#Main" data-toc-modified-id="Main-4">Main</a></span></li><li><span><a href="#PCA" data-toc-modified-id="PCA-5">PCA</a></span></li></ul></div>

# %% [markdown]
# # Dependencies

# %%
library(ggplot2)

# %%
library(ggbiplot)
# Out:
# Loading required package: plyr
#
# Warning message:
# “package ‘plyr’ was built under R version 4.0.5”
# Loading required package: scales
#
# Loading required package: grid

# %% [markdown]
# # Functions

# %%
source("/Users/anabbi/git/ped_CapTCRseq/R/Immune_diversity.R")
source("/Users/anabbi/git/ped_CapTCRseq/R/Misc_functions.R")
source("/Users/anabbi/git/ped_CapTCRseq/R/ggplot2_theme.R")

# %% [markdown]
# # Paths

# %%
datapath <- "/Users/anabbi/OneDrive - UHN/Documents/INTERCEPT/Data/"
plotpath <- "/Users/anabbi/OneDrive - UHN/Documents/INTERCEPT/Plots/"
manifestpath <- "/Users/anabbi/OneDrive - UHN/Documents/INTERCEPT/Manifests/"

gitpath <- "/Users/anabbi/git/ped_CapTCRseq/"

# %% [markdown]
# # Main

# %%
load(file = paste0(gitpath, "data/pbmc_sampleprocessing.RData"))

# %%
metadata <- read.csv(file = paste0(datapath, "INT_metadata_flow.csv"),header = T, stringsAsFactors = F)

# %%
load(file = paste0(datapath,"capTCRseq/divstats_lst_TRA.RData"))
load(file = paste0(datapath,"capTCRseq/divstats_lst_TRB.RData"))

# %%
myfreq <- as.data.frame(table(divstats_lst_TRB$PBMC$Patient.y), stringsAsFactors = F)

# %%
myfreq$disease_type <- metadata$Disease_type[ match(myfreq$Var1, metadata$Patient)]

# %%
morethan1 <- myfreq[ myfreq$Freq > 1,]

# %%
sum(divstats_lst_TRB$PBMC$TRB, na.rm = T)
# Out:
# [1] 66263

# %%
sum(divstats_lst_TRA$PBMC$TRA, na.rm = T)
# Out:
# [1] 149302

# %%
sum(!is.na(divstats_lst_TRB$PBMC$Patient.y))
# Out:
# [1] 260

# %%
summary(divstats_lst_TRB$PBMC$TRB, na.rm = T)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#     1.0    56.0   135.5   254.9   356.5  2237.0     333

# %%
summary(divstats_lst_TRA$PBMC$TRA, na.rm = T)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#     2.0   122.0   278.5   574.2   768.2  5219.0     333

# %%
table($Patient)
# Out:
#   CHP_10YO-M   CHP_11YO-M CHP_15YO-F-A CHP_15YO-F-B   CHP_15YO-M   CHP_16YO-M
#            1            1            1            1            1            1
#  CHP_1YO-M-A  CHP_1YO-M-B    CHP_2YO-M      CHP_303      CHP_315      CHP_319
#            1            1            1            1            1            1
#      CHP_323      CHP_324      CHP_326      CHP_328      CHP_329      CHP_330
#            5            3            1            1            2            2
#      CHP_331      CHP_333      CHP_334      CHP_335      CHP_336      CHP_337
#            3            1            3            3            4            4
#      CHP_338      CHP_339      CHP_340      CHP_341      CHP_342      CHP_343
#            4            4            6            1            2            7
#      CHP_344      CHP_345      CHP_346      CHP_347      CHP_348      CHP_349
#            9            6            1            8            9            3
#      CHP_350      CHP_351      CHP_352      CHP_353      CHP_354      CHP_355
#            7            6            2            8            1            4
#      CHP_356      CHP_357      CHP_358      CHP_359      CHP_360      CHP_361
#            5           10            8            8            8           11
#      CHP_362      CHP_363      CHP_364      CHP_365      CHP_366      CHP_367
#            7            6            7            7            8            6
#      CHP_368      CHP_369      CHP_370      CHP_371      CHP_372      CHP_373
#            7            3            8            5            3            7
#      CHP_374      CHP_375      CHP_376      CHP_377      CHP_378      CHP_379
#            5            7            4            5            7            1
#      CHP_380      CHP_381      CHP_382      CHP_383      CHP_384      CHP_385
#            7            4            7            3            1            6
#      CHP_386      CHP_387      CHP_388      CHP_389      CHP_390      CHP_391
#            5            5            5            6            6            6
#      CHP_392      CHP_393      CHP_394      CHP_395      CHP_396      CHP_397
#            4            3            5            2            6           10
#      CHP_398      CHP_399    CHP_3YO-F  CHP_3YO-M-A  CHP_3YO-M-B      CHP_400
#            4            6            1            1            1            5
#      CHP_401      CHP_402      CHP_403      CHP_404      CHP_405      CHP_406
#            7            5            3            9            8            1
#      CHP_407      CHP_408      CHP_409      CHP_410      CHP_411      CHP_412
#            7            4            4            4            3            6
#      CHP_413      CHP_414      CHP_415      CHP_416      CHP_417      CHP_418
#            3            6            5            3            1            4
#      CHP_419      CHP_420      CHP_421      CHP_422      CHP_423    CHP_5YO-M
#            3            2            1            2            1            1
#    CHP_8MO-F      CHP-328      CHP-342      CHP-351      CHP-353      CHP-363
#            1            2            1            1            1            1
#      CHP-369      CHP-371      CHP-377      CHP-386      CHP-398      CHP-404
#            1            1            1            2            1            1
#      CHP-411      CHP-416      CHP-417 LFS_TCR-4535 LFS_TCR-4570 LFS_TCR-4602
#            1            1            1            1            1            1
# LFS_TCR-4758 LFS_TCR-4759 LFS_TCR-4783 LFS_TCR-4837 LFS_TCR-4838 LFS_TCR-5014
#            1            1            1            1            1            1
# LFS_TCR-5067
#            1

# %%
head(pbmc_samples)
# Out:
#   sample_id Shipped DNAextracted DNAused libbatch
# 1 330-05    n = 320 6160         600     190517_M04827_0203_000000000-D6BYT
# 2 331-05    n = 320 3780         600     190517_M04827_0203_000000000-D6BYT
# 3 331-04    n = 320 9700         600     190517_M04827_0203_000000000-D6BYT
# 4 338-05    n = 320 1410         600     190517_M04827_0203_000000000-D6BYT
# 5 338-04    n = 320 2460         600     190517_M04827_0203_000000000-D6BYT
# 6 342-04    n = 320 1650         600     190517_M04827_0203_000000000-D6BYT
#   librarypassed Library preparation libraryyield captureyield
# 1 Passed        n = 281              825.6       155.42
# 2 Passed        n = 281             1161.6       162.64
# 3 Passed        n = 281             1555.2       162.64
# 4 Passed        n = 281              508.8       328.70
# 5 Passed        n = 281              883.2       328.70
# 6 Passed        n = 281              960.0       144.02
#   capbatch                           capturepassed Successful capture deepseq
# 1 190624_M04827_0214_000000000-D6F66 Passed        n = 277            Yes
# 2 190624_M04827_0214_000000000-D6F66 Passed        n = 277            Yes
# 3 190624_M04827_0214_000000000-D6F66 Passed        n = 277            Yes
# 4 190624_M04827_0214_000000000-D6F66 Passed        n = 277            Yes
# 5 190624_M04827_0214_000000000-D6F66 Passed        n = 277            Yes
# 6 190624_M04827_0214_000000000-D6F66 Passed        n = 277            Yes
#   Deep sequencing mysample_id TCR TCR analysis Patient Tumor  Group
# 1 n = 277         CHP_330_05  Yes n = 253      CHP_330 OS     Solid
# 2 n = 277         CHP_331_05  Yes n = 253      CHP_331 SR ALL Leukemia
# 3 n = 277         CHP_331_04  Yes n = 253      CHP_331 SR ALL Leukemia
# 4 n = 277         CHP_338_05  Yes n = 253      CHP_338 AML    Leukemia
# 5 n = 277         CHP_338_04  Yes n = 253      CHP_338 AML    Leukemia
# 6 n = 277         CHP_342_04  Yes n = 253      CHP_342 AML    Leukemia

# %%
divstats_pbmc <- divstats[ divstats$Sample == "PBMC",]

# %%
dim(divstats_pbmc)
# Out:
# [1] 265  24

# %%
all <- merge(pbmc_samples, divstats_pbmc, by.x = "mysample_id", by.y = "sample_id")

# %%
dim(all)
# Out:
# [1] 254  43

# %%
colnames(all)
# Out:
#  [1] "mysample_id"         "sample_id"           "Shipped"
#  [4] "DNAextracted"        "DNAused"             "libbatch"
#  [7] "librarypassed"       "Library preparation" "libraryyield"
# [10] "captureyield"        "capbatch"            "capturepassed"
# [13] "Successful capture"  "deepseq"             "Deep sequencing"
# [16] "TCR"                 "TCR analysis"        "Patient.x"
# [19] "Tumor"               "Group.x"             "TRB"
# [22] "Reads"               "CPKR"                "Average_reads"
# [25] "VMR"                 "Max_reads"           "Singletons"
# [28] "Doubletons"          "qD"                  "Sample_Coverage"
# [31] "observed_Richness"   "estimated_Richness"  "SE_Richeness"
# [34] "observed_Shannon"    "estimated_Shannon"   "SE_Shannon"
# [37] "observed_Simpson"    "estimated_Simpson"   "SE_Simpson"
# [40] "Sample"              "Group.y"             "Patient.y"
# [43] "Cycle"

# %%
ggplot(data = all, aes( x = DNAused, y = TRB)) + geom_point()
# Out:
# plot without title

# %%
ggplot(data = all, aes( x = libraryyield, y = TRB)) + geom_point()
# Out:
# plot without title

# %%
ggplot(data = all, aes( x = captureyield, y = TRB)) + geom_point()
# Out:
# plot without title

# %%
histp(all, "DNAextracted")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
p <- ggplot(data = all, aes( x = capbatch, y = TRB)) + geom_boxplot() + myplot + myaxis

# %%
p1 <- ggplot(data = all, aes( x = libbatch, y = TRB)) + geom_boxplot() + myplot + myaxis

# %%
pdf(paste0(plotpath, "qc_libbatch.pdf"),
    width = 40, height = 40)
p1
dev.off()
# Out:
# pdf
#   2

# %%
pdf(paste0(plotpath, "qc_capbatch.pdf"),
    width = 40, height = 40)
p
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# # PCA

# %%
colnames(all)
# Out:
#  [1] "mysample_id"         "sample_id"           "Shipped"
#  [4] "DNAextracted"        "DNAused"             "libbatch"
#  [7] "librarypassed"       "Library preparation" "libraryyield"
# [10] "captureyield"        "capbatch"            "capturepassed"
# [13] "Successful capture"  "deepseq"             "Deep sequencing"
# [16] "TCR"                 "TCR analysis"        "Patient.x"
# [19] "Tumor"               "Group.x"             "TRB"
# [22] "Reads"               "CPKR"                "Average_reads"
# [25] "VMR"                 "Max_reads"           "Singletons"
# [28] "Doubletons"          "qD"                  "Sample_Coverage"
# [31] "observed_Richness"   "estimated_Richness"  "SE_Richeness"
# [34] "observed_Shannon"    "estimated_Shannon"   "SE_Shannon"
# [37] "observed_Simpson"    "estimated_Simpson"   "SE_Simpson"
# [40] "Sample"              "Group.y"             "Patient.y"
# [43] "Cycle"

# %%
all_subset <- all[ all$DNAused == 600,]

# %%
summary(all$DNAused)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     0.0   405.2   600.0   454.5   600.0   600.0

# %%
forpca <- all_subset[c("DNAextracted", "libraryyield", "captureyield", "TRB", "Reads")]

# %%
mycancers <- all_subset$Tumor
mylibbatch <- all_subset$libbatch
mycapbatch <- all_subset$capbatch

# %%
my.pca <- prcomp(forpca, center = T, scale. = T)

# %%
plot(my.pca, type = "l")
# Out:
# Plot with title “my.pca”

# %%
g <- ggbiplot(my.pca, #obs.scale = 1, var.scale = 1, 
              groups = mycapbatch, ellipse = TRUE, var.axes = TRUE,
              circle = FALSE) + myplot + myaxis + theme(legend.position = "none")# + scale_color_viridis_b()

# %%
pdf(paste0(plotpath, "pca_plot.pdf"),
    width = 20, height = 20)
g
dev.off()
# Out:
# pdf
#   2
