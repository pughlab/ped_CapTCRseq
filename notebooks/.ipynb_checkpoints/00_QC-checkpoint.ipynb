# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Dependencies" data-toc-modified-id="Dependencies-1">Dependencies</a></span></li><li><span><a href="#Functions" data-toc-modified-id="Functions-2">Functions</a></span></li><li><span><a href="#Paths" data-toc-modified-id="Paths-3">Paths</a></span></li><li><span><a href="#Main" data-toc-modified-id="Main-4">Main</a></span></li><li><span><a href="#PBMC" data-toc-modified-id="PBMC-5">PBMC</a></span><ul class="toc-item"><li><span><a href="#PCA-V-usage" data-toc-modified-id="PCA-V-usage-5.1">PCA V usage</a></span></li><li><span><a href="#PCA-experimental-measures" data-toc-modified-id="PCA-experimental-measures-5.2">PCA experimental measures</a></span></li><li><span><a href="#Remove-samples" data-toc-modified-id="Remove-samples-5.3">Remove samples</a></span></li></ul></li><li><span><a href="#cfDNA" data-toc-modified-id="cfDNA-6">cfDNA</a></span><ul class="toc-item"><li><span><a href="#PCA-V-usage" data-toc-modified-id="PCA-V-usage-6.1">PCA V usage</a></span></li><li><span><a href="#PCA-experimental-measures" data-toc-modified-id="PCA-experimental-measures-6.2">PCA experimental measures</a></span></li><li><span><a href="#Remove-samples" data-toc-modified-id="Remove-samples-6.3">Remove samples</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Dependencies

# %%
pacman::p_load(ggplot2, ggbiplot, immunarch, randomcoloR, cowplot, factoextra, ggbeeswarm)

# %% [markdown]
# # Functions

# %%
source("/Users/anabbi/git/ped_CapTCRseq/R/Immune_diversity.R")
source("/Users/anabbi/git/ped_CapTCRseq/R/Misc_functions.R")
source("/Users/anabbi/git/ped_CapTCRseq/R/ggplot2_theme.R")

# %%
pca_vusage.fx <- function(dta, sampleprocessingdta, sampletype, ell){
    
    #subset to PBMC samples
    dta_subset <- repFilter(dta, .method = "by.meta", .query = list(sample_type = include(sampletype)))
    
    dta_subset$meta <- cbind(dta_subset$meta, sampleprocessingdta[ match( dta_subset$meta$sample_id, 
                                                                  sampleprocessingdta$mysample_id),])
    dta_subset_gu <- as.data.frame(geneUsage(dta_subset$data, "hs.trbv", .norm = T, .quant = "count"))
    rownames(dta_subset_gu) <- dta_subset_gu$Names
dta_subset_gu$Names <- NULL
    dta_subset_gu[is.na(dta_subset_gu)] <- 0
    res.pca <- prcomp(t(dta_subset_gu), scale. = TRUE, center = TRUE)
    p1 <- fviz_eig(res.pca)
    p2 <- fviz_pca_var(res.pca, col.var = "contrib", # Color by contributions to the PC
             gradient.cols = c("#00AFBB", "#E7B800", "#FC4E07"),
             repel = TRUE)
    groups <- as.factor(dta_subset$meta$libbatch)
    myColors <- distinctColorPalette(length(levels(groups)))
    names(myColors) <- levels(groups)
    p3 <- fviz_pca_ind(res.pca,geom = "point", pointshape = 16, pointsize = 1,alpha = 0.7,
                       col.ind = groups, 
                       addEllipses = ell, ellipse.alpha = 0, invisible="quali",
                       title = "Library batch") + 
    theme(legend.position = "none") + scale_color_manual(values = myColors)
    
    groups <- as.factor(dta_subset$meta$capbatch)
    myColors <- distinctColorPalette(length(levels(groups)))
    names(myColors) <- levels(groups)
    p4 <- fviz_pca_ind(res.pca,geom = "point", pointshape = 16, pointsize = 1, alpha = 0.7,
                       col.ind = groups, 
                       addEllipses = ell, ellipse.alpha = 0, invisible="quali",
                       title = "Capture batch") + 
    theme(legend.position = "none") + scale_color_manual(values = myColors)
    
    return(plot_grid(p1,p2,p3,p4))
}

# %%
pca_batch.fx <- function(dta, sampleprocessingdta, sampletype, ell){
    
    meta <- repFilter(dta, .method = "by.meta", .query = list(sample_type = include("PBMC")))$meta
    
    sampleprocessingdta <- sampleprocessingdta[ which(sampleprocessingdta$TCR == "Yes"),]

    meta <- cbind(meta, sampleprocessingdta[ match( meta$sample_id, sampleprocessingdta$mysample_id),])
    
    meta <- meta[!is.na(meta$TCR),]
    
    meta_subset <- meta[, c("TRB", "Reads", "observed_Shannon",
                            "q0_v", "q0_j", "DNAextracted", "DNAused", "libraryyield", "captureyield")]

    rownames(meta_subset) <- meta$sample_id
    
    mypca <- prcomp(meta_subset, scale. = TRUE, center = TRUE)
    
    p1 <-  fviz_eig(mypca)
    
    p2 <- fviz_pca_var(mypca, col.var = "contrib",
             gradient.cols = c("#00AFBB", "#E7B800", "#FC4E07"), repel = TRUE)
    
    groups <- as.factor(meta$libbatch)
    myColors <- distinctColorPalette(length(levels(groups)))
    names(myColors) <- levels(groups)

p3 <- fviz_pca_ind(mypca, geom = "point", pointshape = 16, pointsize = 1,
                   col.ind = groups, alpha = 0.7,
                   addEllipses = ell, ellipse.alpha = 0, invisible="quali",
                   title = "Library batch") + theme(legend.position = "none") +
    scale_color_manual(values = myColors)
    
    groups <- as.factor(meta$capbatch)
    myColors <- distinctColorPalette(length(levels(groups)))
    names(myColors) <- levels(groups)

p4 <- fviz_pca_ind(mypca, geom = "point", pointshape = 16, pointsize = 1,
                   col.ind = groups, alpha = 0.7, 
                   addEllipses = ell, ellipse.alpha = 0, invisible="quali",
                   title = "Capture batch") + theme(legend.position = "none") +
    scale_color_manual(values = myColors)
    
    return(plot_grid(p1,p2,p3,p4))
    
}

# %% [markdown]
# # Paths

# %%
datapath <- "/Users/anabbi/OneDrive - UHN/Documents/INTERCEPT/Data/"
plotpath <- "/Users/anabbi/OneDrive - UHN/Documents/INTERCEPT/Plots/"
manifestpath <- "/Users/anabbi/OneDrive - UHN/Documents/INTERCEPT/Manifests/"

gitpath <- "/Users/anabbi/git/ped_CapTCRseq/"

# %% [markdown]
# # Main

# %%
#assemble_stats <- read.csv(file = paste0(datapath, "capTCRseq/assemble_stats.csv"), header = T)

# %% [markdown]
# # PBMC

# %%
load(file = paste0(gitpath, "data/pbmc_sampleprocessing.RData"))

# %%
load(file = paste0(datapath,"capTCRseq/divstats_lst_TRB.RData"))

# %%
pbmc_samples$sample_id <- NULL

# %%
pbmc_samples
# Out:
#     Shipped DNAextracted DNAused libbatch
# 1   n = 320  6160        600     190517_M04827_0203_000000000-D6BYT
# 2   n = 320  3780        600     190517_M04827_0203_000000000-D6BYT
# 3   n = 320  9700        600     190517_M04827_0203_000000000-D6BYT
# 4   n = 320  1410        600     190517_M04827_0203_000000000-D6BYT
# 5   n = 320  2460        600     190517_M04827_0203_000000000-D6BYT
# 6   n = 320  1650        600     190517_M04827_0203_000000000-D6BYT
# 7   n = 320 13900        600     190517_M04827_0203_000000000-D6BYT
# 8   n = 320  3360        600     190517_M04827_0203_000000000-D6BYT
# 9   n = 320  7420        600     190517_M04827_0203_000000000-D6BYT
# 10  n = 320  3960        600     190517_M04827_0203_000000000-D6BYT
# 11  n = 320  4720        600     190517_M04827_0203_000000000-D6BYT
# 12  n = 320  2520        600     190517_M04827_0203_000000000-D6BYT
190531_M00753_0126_000000000-D6D7Y Passed        n = 277            Yes
# 30  190531_M00753_0126_000000000-D6D7Y Passed        n = 277            Yes
# ⋮   ⋮                                  ⋮             ⋮                  ⋮
# 291 NA                                               NA                 NA
# 292 NA                                               NA                 NA
# 293 NA                                               NA                 NA
# 294 NA                                               NA                 NA
# 295 NA                                               NA                 NA
# 296 NA                                               NA                 NA
# 297 NA                                               NA                 NA
# 298 NA                                               NA                 NA
# 299 NA                                               NA                 NA
# 300 NA                                               NA                 NA
# 301 NA                                               NA                 NA
# 302 NA                                               NA                 NA
# 303 NA                                               NA                 NA
# 304 NA                                               NA                 NA
# 305 NA                                               NA                 NA
# 306 NA                                               NA                 NA
# 307 200123_M04827_0347_000000000-D82GW Passed        n = 277            Yes
# 308 200123_M04827_0347_000000000-D82GW Passed        n = 277            Yes
# 309 200123_M04827_0347_000000000-D82GW Passed        n = 277            Yes
# 310 200123_M04827_0347_000000000-D82GW Passed        n = 277            Yes
# 311 200123_M04827_0347_000000000-D82GW Passed        n = 277            Yes
# 312 200123_M04827_0347_000000000-D82GW Passed        n = 277            Yes
# 313 200123_M04827_0347_000000000-D82GW Passed        n = 277            Yes
# 314 200123_M04827_0347_000000000-D82GW Passed        n = 277            Yes
# 315 200123_M04827_0347_000000000-D82GW Passed        n = 277            Yes
# 316 200123_M04827_0347_000000000-D82GW Passed        n = 277            Yes
# 317 200123_M04827_0347_000000000-D82GW Passed        n = 277            Yes
# 318 200123_M04827_0347_000000000-D82GW Passed        n = 277            Yes
# 319 200123_M04827_0347_000000000-D82GW Passed        n = 277            Yes
# 320 200123_M04827_0347_000000000-D82GW Passed        n = 277            Yes
#     Deep sequencing mysample_id     TCR TCR analysis Patient Tumor  Group
# 1   n = 277         CHP_330_05      Yes n = 272      CHP_330 OS     Solid
# 2   n = 277         CHP_331_05      Yes n = 272      CHP_331 SR ALL Leukemia
# 3   n = 277         CHP_331_04      Yes n = 272      CHP_331 SR ALL Leukemia
# 4   n = 277         CHP_338_05      Yes n = 272      CHP_338 AML    Leukemia
# 5   n = 277         CHP_338_04      Yes n = 272      CHP_338 AML    Leukemia
# 6   n = 277         CHP_342_04      Yes n = 272      CHP_342 AML    Leukemia
# 7   n = 277         CHP_319_05      Yes n = 272      CHP_319 NA     NA
# 8   n = 277         CHP_343_02      Yes n = 272      CHP_343 EWS    Solid
# 9   n = 277         CHP_343_03      Yes n = 272      CHP_343 EWS    Solid
# 10  n = 277         CHP_343_05      Yes n = 272      CHP_343 EWS    Solid
# 11  n = 277         CHP_343_04      Yes n = 272      CHP_343 EWS    Solid
# 12  n = 277         CHP_348_01      Yes n = 272      CHP_348 OS     Solid
# 13  n = 277         CHP_348_02      Yes n = 272      CHP_348 OS     Solid
# 14  n = 277         CHP_348_03      Yes n = 272      CHP_348 OS     Solid
# 15  n = 277         CHP_348_04      Yes n = 272      CHP_348 OS     Solid
# 16  n = 277         CHP_352_02      Yes n = 272      CHP_352 HR ALL Leukemia
# 17  n = 277         CHP_365_02      Yes n = 272      CHP_365 ALL    Leukemia
# 18  n = 277         CHP_346_01      Yes n = 272      CHP_346 NB     Solid
# 19  n = 277         CHP_363_03      Yes n = 272      CHP_363 EWS    Solid
# 20  n = 277         CHP_349_02      Yes n = 272      CHP_349 CML    Leukemia
# 21  n = 277         CHP_349_01      Yes n = 272      CHP_349 CML    Leukemia
# 22  n = 277         CHP_350_02      Yes n = 272      CHP_350 HB     Solid
# 23  n = 277         CHP_350_01      Yes n = 272      CHP_350 HB     Solid
# 24  n = 277         CHP_350_03      Yes n = 272      CHP_350 HB     Solid
# 25  n = 277         CHP_350_04      Yes n = 272      CHP_350 HB     Solid
# 26  n = 277         CHP_351_02      Yes n = 272      CHP_351 OS     Solid
# 27  n = 277         CHP_351_01      Yes n = 272      CHP_351 OS     Solid
# 28  n = 277         CHP_353_02      Yes n = 272      CHP_353 AML    Leukemia
# 29  n = 277         CHP_367_01      Yes n = 272      CHP_367 HR ALL Leukemia
# 30  n = 277         CHP_354_01      Yes n = 272      CHP_354 AML    Leukemia
# ⋮   ⋮               ⋮               ⋮   ⋮            ⋮       ⋮      ⋮
# 291 NA              CHP_403_01      No  NA           CHP_403 NA     NA
# 292 NA              CHP_386_01      No  NA           CHP_386 NA     NA
# 293 NA              CHP_378_05      No  NA           CHP_378 NA     NA
# 294 NA              CHP_367_05      No  NA           CHP_367 NA     NA
# 295 NA              CHP_400_01      No  NA           CHP_400 NA     NA
# 296 NA              CHP_392_03      No  NA           CHP_392 NA     NA
# 297 NA              CHP_380_04      No  NA           CHP_380 NA     NA
# 298 NA              CHP_392_01      No  NA           CHP_392 NA     NA
# 299 NA              CHP_402_01      No  NA           CHP_402 NA     NA
# 300 NA              CHP_388_01      No  NA           CHP_388 NA     NA
# 301 NA              CHP_385_04      No  NA           CHP_385 NA     NA
# 302 NA              CHP_394_02      No  NA           CHP_394 NA     NA
# 303 NA              CHP_375_04      No  NA           CHP_375 NA     NA
# 304 NA              CHP_388_03      No  NA           CHP_388 NA     NA
# 305 NA              CHP_375_03      No  NA           CHP_375 NA     NA
# 306 NA              CHP_367_04      No  NA           CHP_367 NA     NA
# 307 n = 277         CHP_1YO_M_B_00  Yes n = 272      CHP_1YO NA     NA
# 308 n = 277         CHP_3YO_M_A_00  Yes n = 272      CHP_3YO NA     NA
# 309 n = 277         CHP_3YO_F_00    Yes n = 272      CHP_3YO NA     NA
# 310 n = 277         CHP_5YO_M_00    Yes n = 272      CHP_5YO NA     NA
# 311 n = 277         CHP_2YO_M_00    Yes n = 272      CHP_2YO NA     NA
# 312 n = 277         CHP_3YO_M_B_00  Yes n = 272      CHP_3YO NA     NA
# 313 n = 277         CHP_1YO_M_A_00  Yes n = 272      CHP_1YO NA     NA
# 314 n = 277         CHP_10YO_M_00   Yes n = 272      CHP_10Y NA     NA
# 315 n = 277         CHP_15YO_F_A_00 Yes n = 272      CHP_15Y NA     NA
# 316 n = 277         CHP_15YO_F_B_00 Yes n = 272      CHP_15Y NA     NA
# 317 n = 277         CHP_8MO_F_00    Yes n = 272      CHP_8MO NA     NA
# 318 n = 277         CHP_16YO_M_00   Yes n = 272      CHP_16Y NA     NA
# 319 n = 277         CHP_11YO_M_00   Yes n = 272      CHP_11Y NA     NA
# 320 n = 277         CHP_15YO_M_00   Yes n = 272      CHP_15Y NA     NA

# %%
all <- merge(pbmc_samples, divstats_lst_TRB$PBMC, by.x = "mysample_id", by.y = "sample_id")

# divstats_lst_TRB contains all samples with flow data, remove those without tcr data
all <- all[!is.na(all$basename),]

# %%
stats <- read.csv(file = paste0(datapath, "capTCRseq/align_stats.csv"), header = T)

# %%
stats$basename <- gsub("_barcode.*", "",stats$Input.file.s.)

# %%
all_stats <- merge(all, stats, by = "basename")

# %%
dim(all)
# Out:
# [1] 259  78

# %%
dim(all_stats)
# Out:
# [1] 259  96

# %%
all_stats$percaligned <- all_stats$Successfully.aligned.reads/all_stats$Total.sequencing.reads

# %%
summary(all_stats$percaligned)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.6187  0.7295  0.7606  0.7813  0.8468  0.9781

# %%
summary(all_stats$Total.sequencing.reads)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#    95776  2874830  5004723  5644091  6539414 78168018

# %%
summary(all_stats$Successfully.aligned.reads)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#    71989  2202000  3940360  4459634  5200876 59997822

# %%
p1 <- histdenp(all_stats, "Total.sequencing.reads/1000000", 1)
p2 <- histdenp(all_stats, "Successfully.aligned.reads/1000000", 1)
p3 <- histdenp(all_stats, "percaligned", 0.01)

# %%
p4 <- histdenp(all_stats, "TRB", 20)
p5 <- histdenp(all_stats, "Reads/100", 100)

# %%
p6 <- ggplot(data = all_stats, aes( x = DNAused, y = TRB)) + geom_point() + myplot + myaxis
p7 <- ggplot(data = all_stats, aes( x = libraryyield, y = TRB)) + geom_point() + myplot + myaxis
p8 <- ggplot(data = all_stats, aes( x = captureyield, y = TRB)) + geom_point() + myplot + myaxis

# %%
p9 <- ggplot(data = all_stats, aes( x = Total.sequencing.reads/1000000, y = TRB)) + geom_point() + myplot + myaxis
p10 <- ggplot(data = all_stats, aes( x = Successfully.aligned.reads/1000000, y = TRB)) + geom_point() + myplot + myaxis
p11 <- ggplot(data = all_stats, aes( x = percaligned, y = TRB)) + geom_point() + myplot + myaxis

# %%
p12 <- ggplot(data = all_stats, aes( x = capbatch, y = TRB)) + geom_boxplot() +geom_beeswarm(cex = 0.1)+ myplot + myaxis +
theme( axis.text.x = element_blank())
p13 <- ggplot(data = all_stats, aes( x = libbatch, y = TRB)) + geom_boxplot() +geom_beeswarm(cex = 0.5) + myplot + myaxis +
theme( axis.text.x = element_blank())

# %%
pdf(paste0(plotpath, "QC_PBMC.pdf"),
    width = 30, height = 30)
plot_grid(p1,p2, p3, p4, p5,
          p6,p7,p8,p9,p10,
          p11,p12,p13,
          ncol = 3)
dev.off()
# Out:
# pdf
#   2

# %%
summary(all_stats$Total.sequencing.reads)
summary(all_stats$Successfully.aligned.reads)
summary(all_stats$libraryyield)
summary(all_stats$captureyield)
summary(all_stats$percaligned)
summary(all_stats$TRB)
summary(all_stats$Reads)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#    95776  2874830  5004723  5644091  6539414 78168018
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#    71989  2202000  3940360  4459634  5200876 59997822
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    12.0   431.5   691.2   972.2  1228.8  8112.0
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#    6.308   86.070  172.900  298.061  346.750 1311.000
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.6187  0.7295  0.7606  0.7813  0.8468  0.9781
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     1.0    56.0   138.0   255.8   360.0  2237.0
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#      10    1028    3175   33543   33852  363060

# %% [markdown]
# ## PCA V usage

# %%
load(file = paste0(datapath, "capTCRseq/int_load_meta.RData"))

# %%
pbmc_pca <- pca_vusage.fx(int_load, pbmc_samples, "PBMC", "FALSE")

# %%
pbmc_pca
# Out:
# Warning message:
# “ggrepel: 58 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title

# %%
pdf(paste0(plotpath, "PBMC_Vusage_PCA.pdf"),
    width = 10, height = 10)
pbmc_pca
dev.off()
# Out:
# Warning message:
# “ggrepel: 56 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# pdf
#   2

# %% [markdown]
# ## PCA experimental measures

# %%
pca_batch <- pca_batch.fx(int_load, pbmc_samples, "PBMC", "FALSE")

# %%
pca_batch
# Out:
# plot without title

# %%
pdf(paste0(plotpath, "PBMC_batch_PCA.pdf"),
    width = 10, height = 10)
pca_batch
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# ## Remove samples

# %%
summary(all_stats$Total.sequencing.reads)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#    95776  2874830  5004723  5644091  6539414 78168018

# %%
# remove 22 samples with < 2mil reads
subset_pbmc <- all_stats[all_stats$Total.sequencing.reads > 2000000,]

# %%
#remove 10 samples with < 70% reads aligned
subset_pbmc <- subset_pbmc[subset_pbmc$percaligned >= 0.7,]

# %%
save(subset_pbmc, file = paste0(datapath, "capTCRseq/PBMC_GoodSamples.RData"))

# %%
dim(subset_pbmc)
# Out:
# [1] 227  97

# %%
summary(subset_pbmc$TRB)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     2.0    75.0   160.0   277.5   383.5  2237.0

# %%
all_stats[ grepl("411-02", all_stats$basename), "Naïve"]
all_stats[ grepl("385-03", all_stats$basename),"TRB"]
# Out:
# [1] 31
# [1] 3

# %%
stats[ grepl("CHP-411-02-PBMC-DNA", stats$Input.file.s.),]
# Out:
#     Input.file.s.
# 300 CHP-411-02-PBMC-DNA_barcode_R1.fastq,CHP-411-02-PBMC-DNA_barcode_R2.fastq
#     Output.file.s.
# 300  /cluster/projects/pughlab/projects/INTERCEPT/NextSeq/remaining_batch_4_28June2021/mixcr/alignments/alignments_CHP-411-02-PBMC-DNA.vdjca
#     Version               Total.sequencing.reads Successfully.aligned.reads
# 300  2.1.12,repseqio.v1.5 2490276                2272392
#     Alignment.failed..no.hits..not.TCR.IG..
# 300 69658
#     Alignment.failed.because.of.absence.of.CDR3.parts
# 300 26425
#     Alignment.failed.because.of.low.total.score Alignment.aided.overlaps
# 300 121801                                      49521
#     TRA.chains TRB.chains TRD.chains TRG.chains TRA.TRD.chains IGH.chains
# 300 940026     242188     17601      415881     656693         0
#     IGK.chains IGL.chains chains basename
# 300 0          0          0      CHP-411-02-PBMC-DNA

# %%
stats[ grepl("CHP_385-03-PBMC", stats$Input.file.s.),]
# Out:
#     Input.file.s.
# 387 CHP_385-03-PBMC-DNA_barcode_R1.fastq,CHP_385-03-PBMC-DNA_barcode_R2.fastq
#     Output.file.s.
# 387  /cluster/projects/pughlab/projects/INTERCEPT/NextSeq/batch8_14Jan2020/mixcr/alignments/alignments_CHP_385-03-PBMC-DNA.vdjca
#     Version               Total.sequencing.reads Successfully.aligned.reads
# 387  2.1.12,repseqio.v1.5 5934469                4308810
#     Alignment.failed..no.hits..not.TCR.IG..
# 387 487066
#     Alignment.failed.because.of.absence.of.CDR3.parts
# 387 98114
#     Alignment.failed.because.of.low.total.score Alignment.aided.overlaps
# 387 1040479                                     65612
#     TRA.chains TRB.chains TRD.chains TRG.chains TRA.TRD.chains IGH.chains
# 387 3262934    402731     165232     266952     210700         149
#     IGK.chains IGL.chains chains basename
# 387 101        11         0      CHP_385-03-PBMC-DNA

# %%
dim(all)
dim(all_stats)
# Out:
# [1] 259  78
# [1] 259  97

# %% [markdown]
# # cfDNA

# %%
load(file = paste0(gitpath, "data/cfdna_sampleprocessing.RData"))

# %%
load(file = paste0(datapath,"capTCRseq/divstats_lst_TRB.RData"))

# %%
cfdna_samples$sample_id <- NULL

# %%
all <- merge(cfdna_samples, divstats_lst_TRB$cfDNA, by.x = "mysample_id", by.y = "sample_id")

# divstats_lst_TRB contains all samples with flow data, remove those without tcr data
all <- all[!is.na(all$basename),]

# %%
dim(all)
# Out:
# [1] 279  79

# %%
stats <- read.csv(file = paste0(datapath, "capTCRseq/align_stats.csv"), header = T)

# %%
stats$basename <- gsub("_barcode.*", "",stats$Input.file.s.)

# %%
all_stats <- merge(all, stats, by = "basename")

# %%
dim(all)
# Out:
# [1] 279  79

# %%
dim(all_stats)
# Out:
# [1] 279  97

# %%
head(all_stats)
# Out:
#   basename         mysample_id DNA samples DNAextracted DNAused librarypassed
# 1 CHP_315-05_cfDNA CHP_315_05  n = 316      60.64       20.000  Passed
# 2 CHP_323-03_cfDNA CHP_323_03  n = 316     142.96       20.000  Passed
# 3 CHP_323-05_cfDNA CHP_323_05  n = 316      39.56       20.000  Passed
# 4 CHP_324-04_cfDNA CHP_324_04  n = 316      99.84       20.000  Passed
# 5 CHP_324-05_cfDNA CHP_324_05  n = 316      17.16        9.576  Passed
# 6 CHP_326-05_cfDNA CHP_326_05  n = 316      12.68        9.432  Passed
#   libbatch                           Library preparation libraryyield
# 1 200117_M04827_0343_000000000-D82R9 n = 316             338.88
# 2 191017_M04827_0284_000000000-D77P2 n = 316             305.28
# 3 200117_M04827_0343_000000000-D82R9 n = 316             614.40
# 4 200108_M04827_0336_000000000-D7Y8P n = 316             264.00
# 5 200213_M04827_0362_000000000-D8682 n = 316             330.24
# 6 200213_M04827_0362_000000000-D8682 n = 316             314.88
#   DNAforcapture ⋯ Alignment.aided.overlaps TRA.chains TRB.chains TRD.chains
# 1 338.88        ⋯ 55862                    2296658    201791      79982
# 2 305.28        ⋯ 64220                    3553899    549158     111175
# 3 501.44        ⋯ 46328                    2772203    255738     101783
# 4 264.00        ⋯ 11544                    1918562    560107     102545
# 5 330.24        ⋯ 17180                    1012748    193564      39073
# 6 314.88        ⋯ 19627                    1074994    218543      36623
#   TRG.chains TRA.TRD.chains IGH.chains IGK.chains IGL.chains chains
# 1 283073     2928328         18         0         29         0
# 2 593458     4272584        128         0          0         0
# 3 378530     3919109          0         0          0         0
# 4 159952      459396         78        28         28         0
# 5  89307     2693686         43        62          0         0
# 6 159705     2667817        128         0          0         0

# %%
all_stats$percaligned <- all_stats$Successfully.aligned.reads/all_stats$Total.sequencing.reads

# %%
summary(all_stats$percaligned)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.6693  0.8329  0.8667  0.8404  0.8813  0.9278

# %%
summary(all_stats$Total.sequencing.reads)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#    22839  3912810  4882897  5783112  6735700 18558893

# %%
summary(all_stats$Successfully.aligned.reads)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#    20740  3151284  4236306  4919078  5892778 16382810

# %%
p1 <- histdenp(all_stats, "Total.sequencing.reads/1000000", 1)
p2 <- histdenp(all_stats, "Successfully.aligned.reads/1000000", 1)
p3 <- histdenp(all_stats, "percaligned", 0.01)

# %%
p4 <- histdenp(all_stats, "TRB", 5)
p5 <- histdenp(all_stats, "Reads/100", 5)

# %%
p6 <- ggplot(data = all_stats, aes( x = DNAused, y = TRB)) + geom_point() + myplot + myaxis
p7 <- ggplot(data = all_stats, aes( x = libraryyield, y = TRB)) + geom_point() + myplot + myaxis
p8 <- ggplot(data = all_stats, aes( x = captureyield, y = TRB)) + geom_point() + myplot + myaxis

# %%
p9 <- ggplot(data = all_stats, aes( x = Total.sequencing.reads/1000000, y = TRB)) + geom_point() + myplot + myaxis
p10 <- ggplot(data = all_stats, aes( x = Successfully.aligned.reads/1000000, y = TRB)) + geom_point() + myplot + myaxis
p11 <- ggplot(data = all_stats, aes( x = percaligned, y = TRB)) + geom_point() + myplot + myaxis

# %%
p12 <- ggplot(data = all_stats, aes( x = capbatch, y = TRB)) + geom_boxplot() +geom_beeswarm(cex = 0.1)+ myplot + myaxis +
theme( axis.text.x = element_blank())
p13 <- ggplot(data = all_stats, aes( x = libbatch, y = TRB)) + geom_boxplot() +geom_beeswarm(cex = 0.5) + myplot + myaxis +
theme( axis.text.x = element_blank())

# %%
pdf(paste0(plotpath, "QC_cfDNA.pdf"),
    width = 30, height = 30)
plot_grid(p1,p2, p3, p4, p5, p6,p7,p8,p9,p10, p11,p12,p13, ncol = 3)
dev.off()
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_point).”
# pdf
#   2

# %%
summary(all_stats$Total.sequencing.reads)
summary(all_stats$Successfully.aligned.reads)
summary(all_stats$libraryyield)
summary(all_stats$captureyield)
summary(all_stats$percaligned)
summary(all_stats$TRB)
summary(all_stats$Reads)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#    22839  3912810  4882897  5783112  6735700 18558893
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#    20740  3151284  4236306  4919078  5892778 16382810
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   30.82  202.08  324.48  350.17  454.08 1017.60
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#   104.5   327.8   585.2   631.4   863.5  1641.6       1
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.6693  0.8329  0.8667  0.8404  0.8813  0.9278
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    1.00    3.00    7.00   13.94   16.00  220.00
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#       1     356    2962    6515    7858   88874

# %% [markdown]
# ## PCA V usage

# %%
load(file = paste0(gitpath, "data/cfdna_sampleprocessing.RData"))

# %%
load(file = paste0(datapath,"capTCRseq/divstats_lst_TRB.RData"))

# %%
load(file = paste0(datapath, "capTCRseq/int_load_meta.RData"))

# %%
cfdna_pca <- pca_vusage.fx(int_load, cfdna_samples, "cfDNA", "FALSE")

# %%
cfdna_pca
# Out:
# Warning message:
# “ggrepel: 58 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title

# %%
pdf(paste0(plotpath, "cfDNA_Vusage_PCA.pdf"),
    width = 10, height = 10)
cfdna_pca
dev.off()
# Out:
# Warning message:
# “ggrepel: 54 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# pdf
#   2

# %%
CHP_374-05-cfDNA

# %%
head(int_load$meta)
# Out:
#   Sample                sample_id       Patient.x cycle FOLD ATC Age
# 1 CHP_10YO-M_PBMC_DNA   CHP_10YO_M_00   NA        NA    NA   NA  NA
# 2 CHP_11YO-M_PBMC_DNA   CHP_11YO_M_00   NA        NA    NA   NA  NA
# 3 CHP_15YO-F-A_PBMC_DNA CHP_15YO_F_A_00 NA        NA    NA   NA  NA
# 4 CHP_15YO-F-B_PBMC_DNA CHP_15YO_F_B_00 NA        NA    NA   NA  NA
# 5 CHP_15YO-M_PBMC_DNA   CHP_15YO_M_00   NA        NA    NA   NA  NA
# 6 CHP_16YO-M_PBMC_DNA   CHP_16YO_M_00   NA        NA    NA   NA  NA
#   Disease_type TE_fold Pass ⋯ q0_aa q0_v q0_j q0_aav q0_vj q1_aa     q1_v
# 1 NA           NA      NA   ⋯ 22    16    8   22     12.0  12.787814  9.563643
# 2 NA           NA      NA   ⋯ 21    15   11   21     13.0  14.411620 11.695680
# 3 NA           NA      NA   ⋯ 13    12    8   13     10.0  10.930258  9.683620
# 4 NA           NA      NA   ⋯  9     8    7    9      7.5   8.294830  6.692670
# 5 NA           NA      NA   ⋯ 33    22   10   33     16.0  29.070103 20.127211
# 6 NA           NA      NA   ⋯  7     6    6    7      6.0   5.495512  5.434412
#   q1_j     q1_aav    q1_vj
# 1 5.074581 12.787814  7.319112
# 2 8.890122 14.411620 10.292901
# 3 6.059679 10.930258  7.871649
# 4 6.084720  8.294830  6.388695
# 5 7.641330 29.070103 13.884271
# 6 4.355165  5.495512  4.894789

# %%
temp <- repFilter(int_load, .method = "by.meta", .query = list(Sample = exclude("CHP_374-05-cfDNA")))

# %%
cfdna_pca <- pca_vusage.fx(temp, cfdna_samples, "cfDNA", "FALSE")

# %%
cfdna_pca
# Out:
# Warning message:
# “ggrepel: 58 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title

# %% [markdown]
# ## PCA experimental measures

# %%
pca_batch <- pca_batch.fx(int_load, cfdna_samples, "cfDNA", "FALSE")

# %%
pca_batch
# Out:
# plot without title

# %%
pdf(paste0(plotpath, "cfDNA_batch_PCA.pdf"),
    width = 10, height = 10)
pca_batch
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# ## Remove samples

# %%
summary(all_stats$Total.sequencing.reads)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#    22839  3912810  4882897  5783112  6735700 18558893

# %%
summary(all_stats$percaligned)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.6693  0.8329  0.8667  0.8404  0.8813  0.9278

# %%
# remove 20 samples with < 3mil reads
subset_cfdna <- all_stats[all_stats$Total.sequencing.reads > 3000000,]

# %%
#remove 4 samples with < 70% reads aligned
subset_cfdna <- subset_cfdna[subset_cfdna$percaligned >= 0.7,]

# %%
dim(subset_cfdna)
# Out:
# [1] 255  98

# %%
#identify the one outlier from V usage

# %%
dta <- repFilter(int_load, .method = "by.meta", .query = list(sample_type = include("cfDNA")))
dta$meta <- cbind(dta$meta, cfdna_samples[match(dta$meta$sample_id, cfdna_samples$mysample_id), ])
dta_gu <- as.data.frame(geneUsage(dta$data, "hs.trbv", .norm = T, .quant = "count"))
rownames(dta_gu) <- dta_gu$Names
dta_gu$Names <- NULL
dta_gu[is.na(dta_gu)] <- 0
res.pca <- prcomp(t(dta_gu), scale. = TRUE, center = TRUE)

# %%
ind <- get_pca_ind(res.pca)

# %%
ind$coord[ order(ind$coord[,1]), ,drop = FALSE]
# Out:
#                  Dim.1      Dim.2        Dim.3       Dim.4       Dim.5
# CHP_382-04_cfDNA -0.6991776 -8.628632283  3.7240777   1.18752722   0.38841495
# CHP_368-01_cfDNA -0.6021690 -5.488938671  3.0686903   0.11562821   1.44512275
# CHP_323-05_cfDNA -0.5776277 -0.881722199 -0.1616705  -4.69552773 -10.38035397
# CHP_404-02_cfDNA -0.5668566 -6.118269561  1.0060062   4.73987614   0.65040512
# CHP_375-03_cfDNA -0.4403150 -2.476137489  0.2731773  -1.23200999  -2.13041900
# CHP_360-05_cfDNA -0.4278402 -0.593453182  0.3805068  -2.45636042  -2.07706955
# CHP_390-02_cfDNA -0.4258505 -2.696161033  2.1727309  -1.34853064   0.81124523
# CHP_391-03_cfDNA -0.4127562 -1.383796575  1.3708096   0.17904379  -0.54417312
# CHP_367-05_cfDNA -0.4115584  0.951955955 -0.3654828  -0.08778693   1.44842534
