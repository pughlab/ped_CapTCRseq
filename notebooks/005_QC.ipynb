# %%
Sys.setlocale(category = "LC_ALL", locale = "en_US.UTF-8")
# Out:
# [1] "en_US.UTF-8/en_US.UTF-8/en_US.UTF-8/C/en_US.UTF-8/C"

# %% [markdown]
# # Dependencies

# %%
pacman::p_load(ggplot2,  immunarch, randomcoloR, cowplot, factoextra, ggbeeswarm)

# %% [markdown]
# # Functions

# %%
source("/Users/anabbi/git/ped_CapTCRseq/R/Immune_diversity.R")
source("/Users/anabbi/git/ped_CapTCRseq/R/Misc_functions.R")
source("/Users/anabbi/git/ped_CapTCRseq/R/ggplot2_theme.R")

# %%
pca_vusage.fx <- function(dta, sampleprocessingdta, sampletype, ell) {
    # subset to PBMC samples
    dta_subset <- repFilter(dta, .method = "by.meta", .query = list(sampletype = include(sampletype)))

    dta_subset$meta <- cbind(dta_subset$meta, sampleprocessingdta[match(
        dta_subset$meta$sample_id,
        sampleprocessingdta$mysample_id
    ), ])
    dta_subset_gu <- as.data.frame(geneUsage(dta_subset$data, "hs.trbv", .norm = T, .quant = "count"))
    rownames(dta_subset_gu) <- dta_subset_gu$Names
    dta_subset_gu$Names <- NULL
    dta_subset_gu[is.na(dta_subset_gu)] <- 0
    res.pca <- prcomp(t(dta_subset_gu), scale. = TRUE, center = TRUE)
    p1 <- fviz_eig(res.pca)
    p2 <- fviz_pca_var(res.pca,
        col.var = "contrib", # Color by contributions to the PC
        gradient.cols = c("#00AFBB", "#E7B800", "#FC4E07"),
        repel = TRUE
    )
    groups <- as.factor(dta_subset$meta$libbatch)
    myColors <- distinctColorPalette(length(levels(groups)))
    names(myColors) <- levels(groups)
    p3 <- fviz_pca_ind(res.pca,
        geom = "point", pointshape = 16, pointsize = 1, alpha = 0.7,
        col.ind = groups,
        addEllipses = ell, ellipse.alpha = 0, invisible = "quali",
        title = "Library batch"
    ) +
        theme(legend.position = "none") + scale_color_manual(values = myColors)

    groups <- as.factor(dta_subset$meta$capbatch)
    myColors <- distinctColorPalette(length(levels(groups)))
    names(myColors) <- levels(groups)
    p4 <- fviz_pca_ind(res.pca,
        geom = "point", pointshape = 16, pointsize = 1, alpha = 0.7,
        col.ind = groups,
        addEllipses = ell, ellipse.alpha = 0, invisible = "quali",
        title = "Capture batch"
    ) +
        theme(legend.position = "none") + scale_color_manual(values = myColors)

    return(plot_grid(p1, p2, p3, p4))
}

# %%
pca_batch.fx <- function(dta, sampleprocessingdta, sampletype, ell){
    
    meta <- repFilter(dta, .method = "by.meta", .query = list(sampletype = include("PBMC")))$meta
    
    sampleprocessingdta <- sampleprocessingdta[ which(sampleprocessingdta$TCR == "Yes"),]

    meta <- cbind(meta, sampleprocessingdta[ match( meta$sample_id, sampleprocessingdta$mysample_id),])
    
    meta <- meta[!is.na(meta$TCR),]
    
    meta_subset <- meta[, c("TRB", "Reads", "observed_Shannon",
                            "q0_v", "q0_j", "DNAextracted", "DNAused", "libraryyield", "captureyield")]

    rownames(meta_subset) <- meta$sample_id
    
    mypca <- prcomp(meta_subset, scale. = TRUE, center = TRUE)
    
    p1 <-  fviz_eig(mypca)
    
    p2 <- fviz_pca_var(mypca, col.var = "contrib",
             gradient.cols = c("#00AFBB", "#E7B800", "#FC4E07"), repel = TRUE)
    
    groups <- as.factor(meta$libbatch)
    myColors <- distinctColorPalette(length(levels(groups)))
    names(myColors) <- levels(groups)

p3 <- fviz_pca_ind(mypca, geom = "point", pointshape = 16, pointsize = 1,
                   col.ind = groups, alpha = 0.7,
                   addEllipses = ell, ellipse.alpha = 0, invisible="quali",
                   title = "Library batch") + theme(legend.position = "none") +
    scale_color_manual(values = myColors)
    
    groups <- as.factor(meta$capbatch)
    myColors <- distinctColorPalette(length(levels(groups)))
    names(myColors) <- levels(groups)

p4 <- fviz_pca_ind(mypca, geom = "point", pointshape = 16, pointsize = 1,
                   col.ind = groups, alpha = 0.7, 
                   addEllipses = ell, ellipse.alpha = 0, invisible="quali",
                   title = "Capture batch") + theme(legend.position = "none") +
    scale_color_manual(values = myColors)
    
    return(plot_grid(p1,p2,p3,p4))
    
}

# %% [markdown]
# # Paths

# %%
datapath <- "/Users/anabbi/OneDrive - UHN/Documents/INTERCEPT/Data/"
plotpath <- "/Users/anabbi/OneDrive - UHN/Documents/INTERCEPT/Plots/"
manifestpath <- "/Users/anabbi/OneDrive - UHN/Documents/INTERCEPT/Manifests/"

gitpath <- "/Users/anabbi/git/ped_CapTCRseq/"

# %% [markdown]
# # Main

# %% [markdown]
# # PBMC

# %%
load(file = paste0(gitpath, "data/pbmc_sampleprocessing.RData"))

# %%
load(file = paste0(datapath,"capTCRseq/meta_div_TRB.RData"))

# %%
pbmc_samples$sample_id <- NULL

# %%
pbmc_samples[ grepl("358", pbmc_samples$Patient),]
# Out:
#    Shipped DNAextracted DNAused libbatch
# 35 n = 321 50600        600     190521_M04827_0204_000000000-D6BKL
# 52 n = 321 18800        600     190607_M04827_0206_000000000-D6C75
# 71 n = 321  6540        600     190613_M04827_0211_000000000-D6D4V
# 75 n = 321  6800        600     190613_M04827_0211_000000000-D6D4V
#    librarypassed Library preparation libraryyield captureyield
# 35 Passed        n = 282              787.2        21.66
# 52 Passed        n = 282             3955.2        64.22
# 71 Passed        n = 282              427.2        75.62
# 75 Passed        n = 282             1641.6       172.14
#    capbatch                           capturepassed Successful capture deepseq
# 35 190531_M00753_0126_000000000-D6D7Y Passed        n = 278            Yes
# 52 D6WFR                              Passed        n = 278            Yes
# 71 D6VVR                              Passed        n = 278            Yes
# 75 D6VVR                              Passed        n = 278            Yes
#    Deep sequencing mysample_id TCR TCR analysis Patient Tumor Group
# 35 n = 278         CHP_358_01  No  n = 278      CHP_358 NA    NA
# 52 n = 278         CHP_358_02  No  n = 278      CHP_358 NA    NA
# 71 n = 278         CHP_358_05  No  n = 278      CHP_358 NA    NA
# 75 n = 278         CHP_358_03  No  n = 278      CHP_358 NA    NA

# %%
meta_div[ grepl("407_01", meta_div$sample_id),]
# Out:
#      sample_id  Patient cycle FOLD ATC    Age Disease_type TE_fold CD3  EM  ...
# 249  CHP_407_01 CHP_407 X01   1    216.81 12  DLBCL        1       2219 735 ...
# 741  CHP_407_01 CHP_407 X01   1    216.81 12  DLBCL        1       2219 735 ...
# 4411 CHP_407_01 CHP_407 X00   1    216.81 12  DLBCL        1       2219 735 ...
#      observed_Shannon estimated_Shannon SE_Shannon observed_Simpson
# 249  4.315            4.317             0.030      4.006
# 741     NA               NA                NA         NA
# 4411 3.244            3.245             0.023      2.905
#      estimated_Simpson SE_Simpson basename
# 249  4.008             0.028      CHP_407-01_cfDNA
# 741     NA                NA      NA
# 4411 2.905             0.020      CHP_407-FFPE-DNA_S7
#      file
# 249  remaining_batch_3_cfDNA_15April2021/mixcr/clones/CLONES_TRBCHP_407-01_cfDNA.txt
# 741  NA
# 4411 batchFFPE_3Apr2020/mixcr/clones/CLONES_TRBCHP_407-FFPE-DNA_S7.txt
#      sampletype Group
# 249  cfDNA      CHP
# 741  PBMC       CHP
# 4411 Tumor      CHP

# %%
table(meta_div$sampletype[!is.na(meta_div$TRB)])
# Out:
# cfDNA  PBMC Tumor
#   278   282    17

# %%
all <- merge(pbmc_samples, meta_div[ which(meta_div$sampletype == "PBMC"),], by.x = "mysample_id", by.y = "sample_id")

# divstats_lst_TRB contains all samples with flow data, remove those without tcr data
all <- all[!is.na(all$basename),]

# %%
dim(all)
# Out:
# [1] 272  83

# %%
pbmc_samples[ grepl("LFS", pbmc_samples$mysample_id),]
# Out:
#      Shipped DNAextracted DNAused libbatch librarypassed Library preparation
#      libraryyield captureyield capbatch capturepassed Successful capture
#      deepseq Deep sequencing mysample_id TCR TCR analysis Patient Tumor Group

# %%
stats <- read.csv(file = paste0(datapath, "capTCRseq/align_stats.csv"), header = T)

# %%
dim(stats)
# Out:
# [1] 603  19

# %%
stats$basename <- gsub("_barcode.*", "",stats$Input.file.s.)

# %%
all_stats <- merge(all, stats, by = "basename")

# %%
dim(all)
# Out:
# [1] 272  83

# %%
tmp <- (meta_div[!is.na(meta_div$TRB),])
tmp <- tmp[ tmp$sampletype == "PBMC",]

# %%
dim(tmp)
# Out:
# [1] 282  65

# %%
(tmp$sample_id[ !tmp$sample_id %in% all_stats$mysample_id])
# Out:
#  [1] "LFS_TCR_4535_00" "LFS_TCR_4570_00" "LFS_TCR_4602_00" "LFS_TCR_4758_00"
#  [5] "LFS_TCR_4759_00" "LFS_TCR_4783_00" "LFS_TCR_4837_00" "LFS_TCR_4838_00"
#  [9] "LFS_TCR_5014_00" "LFS_TCR_5067_00"

# %%
head(all_stats)
# Out:
#   basename              mysample_id     Shipped DNAextracted DNAused
# 1 CHP_10YO-M_PBMC_DNA   CHP_10YO_M_00   n = 321  4120        600
# 2 CHP_11YO-M_PBMC_DNA   CHP_11YO_M_00   n = 321  4880        600
# 3 CHP_15YO-F-A_PBMC_DNA CHP_15YO_F_A_00 n = 321 18200        600
# 4 CHP_15YO-F-B_PBMC_DNA CHP_15YO_F_B_00 n = 321 35400        600
# 5 CHP_15YO-M_PBMC_DNA   CHP_15YO_M_00   n = 321  7920        600
# 6 CHP_16YO-M_PBMC_DNA   CHP_16YO_M_00   n = 321  3460        600
#   libbatch                           librarypassed Library preparation
# 1 191220_M04827_0327_000000000-D7W4D Passed        n = 282
# 2 191220_M04827_0327_000000000-D7W4D Passed        n = 282
# 3 191220_M04827_0327_000000000-D7W4D Passed        n = 282
# 4 191220_M04827_0327_000000000-D7W4D Passed        n = 282
# 5 191220_M04827_0327_000000000-D7W4D Passed        n = 282
# 6 191220_M04827_0327_000000000-D7W4D Passed        n = 282
#   libraryyield captureyield ... Alignment.aided.overlaps TRA.chains TRB.chains
# 1 1449.6       13.338       ...  89607                   2500371    369721
# 2 1948.8        6.232       ... 154030                   3481524    550846
# 3 1545.6        7.942       ... 123671                   3488717    549330
# 4 1171.2        7.942       ... 178259                   5292852    875254
# 5 1843.2        6.232       ... 189814                   4275428    660748
# 6 2227.2        4.294       ... 117485                   3382456    472114
#   TRD.chains TRG.chains TRA.TRD.chains IGH.chains IGK.chains IGL.chains chains
# 1  74186     428666     1713555           0        563       0          0
# 2 116455     489440     2318341           0          0       0          0
# 3 157638     486162     1686316        1052          0       0          0
# 4 241875     663487     2991528         793        309       0          0
# 5 130568     632122     2711248           0       1072       0          0
# 6 117300     452204     2111692           0          0       0          0

# %%
dim(all_stats) # minus 10 LFS
# Out:
# [1] 272 101

# %%
all_stats$percaligned <- all_stats$Successfully.aligned.reads/all_stats$Total.sequencing.reads

# %%
all_stats[ grepl("324", all_stats$basename),]
# Out:
#    basename            mysample_id Shipped DNAextracted DNAused
# 14 CHP_324-05_PBMC-DNA CHP_324_05  n = 321 400          107.6
#    libbatch                           librarypassed Library preparation
# 14 191210_M04827_0319_000000000-D7M28 Passed        n = 282
#    libraryyield captureyield ... TRA.chains TRB.chains TRD.chains TRG.chains
# 14 1372.8       744.8        ... 2017528    210124     45860      625207
#    TRA.TRD.chains IGH.chains IGK.chains IGL.chains chains percaligned
# 14 3567562        328        148        16         0      0.8251416

# %%
summary(all_stats$percaligned)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.6187  0.7307  0.7611  0.7804  0.8408  0.9781

# %%
summary(all_stats$Total.sequencing.reads)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#    95776  2978500  5208360  5821431  6835648 78168018

# %%
summary(all_stats$Successfully.aligned.reads)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#    71989  2274299  4089644  4589625  5381270 59997822

# %%
p1 <- histdenp(all_stats, "Total.sequencing.reads/1000000", 1)
p2 <- histdenp(all_stats, "Successfully.aligned.reads/1000000", 1)
p3 <- histdenp(all_stats, "percaligned", 0.01)
# Out:
# Warning message:
# “Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.”

# %%
p4 <- histdenp(all_stats, "TRB", 20)
p5 <- histdenp(all_stats, "Reads/100", 100)

# %%
p00 <- histdenp(all_stats, "DNAused", 30)

# %%
p00
# Out:
# plot without title

# %%
p6 <- ggplot(data = all_stats, aes( x = DNAused, y = TRB)) + geom_point() + myplot + myaxis
p7 <- ggplot(data = all_stats, aes( x = libraryyield, y = TRB)) + geom_point() + myplot + myaxis
p8 <- ggplot(data = all_stats, aes( x = captureyield, y = TRB)) + geom_point() + myplot + myaxis

# %%
p9 <- ggplot(data = all_stats, aes( x = Total.sequencing.reads/1000000, y = TRB)) + geom_point() + myplot + myaxis
p10 <- ggplot(data = all_stats, aes( x = Successfully.aligned.reads/1000000, y = TRB)) + geom_point() + myplot + myaxis
p11 <- ggplot(data = all_stats, aes( x = percaligned, y = TRB)) + geom_point() + myplot + myaxis

# %%
p12 <- ggplot(data = all_stats, aes( x = capbatch, y = TRB)) + geom_boxplot() +geom_beeswarm(cex = 0.1)+ myplot + myaxis +
theme( axis.text.x = element_blank())
p13 <- ggplot(data = all_stats, aes( x = libbatch, y = TRB)) + geom_boxplot() +geom_beeswarm(cex = 0.5) + myplot + myaxis +
theme( axis.text.x = element_blank())

# %%
pdf(paste0(plotpath, "QC_PBMC.pdf"),
    width = 30, height = 30)
plot_grid(p1,p2, p3, p4, p5,
          p6,p7,p8,p9,p10,
          p11,p12,p13,
          ncol = 3)
dev.off()
# Out:
# pdf
#   2

# %%
head(all_stats)
# Out:
#   basename              mysample_id     Shipped DNAextracted DNAused
# 1 CHP_10YO-M_PBMC_DNA   CHP_10YO_M_00   n = 321  4120        600
# 2 CHP_11YO-M_PBMC_DNA   CHP_11YO_M_00   n = 321  4880        600
# 3 CHP_15YO-F-A_PBMC_DNA CHP_15YO_F_A_00 n = 321 18200        600
# 4 CHP_15YO-F-B_PBMC_DNA CHP_15YO_F_B_00 n = 321 35400        600
# 5 CHP_15YO-M_PBMC_DNA   CHP_15YO_M_00   n = 321  7920        600
# 6 CHP_16YO-M_PBMC_DNA   CHP_16YO_M_00   n = 321  3460        600
#   libbatch                           librarypassed Library preparation
# 1 191220_M04827_0327_000000000-D7W4D Passed        n = 282
# 2 191220_M04827_0327_000000000-D7W4D Passed        n = 282
# 3 191220_M04827_0327_000000000-D7W4D Passed        n = 282
# 4 191220_M04827_0327_000000000-D7W4D Passed        n = 282
# 5 191220_M04827_0327_000000000-D7W4D Passed        n = 282
# 6 191220_M04827_0327_000000000-D7W4D Passed        n = 282
#   libraryyield captureyield ... TRA.chains TRB.chains TRD.chains TRG.chains
# 1 1449.6       13.338       ... 2500371    369721      74186     428666
# 2 1948.8        6.232       ... 3481524    550846     116455     489440
# 3 1545.6        7.942       ... 3488717    549330     157638     486162
# 4 1171.2        7.942       ... 5292852    875254     241875     663487
# 5 1843.2        6.232       ... 4275428    660748     130568     632122
# 6 2227.2        4.294       ... 3382456    472114     117300     452204
#   TRA.TRD.chains IGH.chains IGK.chains IGL.chains chains percaligned
# 1 1713555           0        563       0          0      0.7415962
# 2 2318341           0          0       0          0      0.7540386
# 3 1686316        1052          0       0          0      0.7519197
# 4 2991528         793        309       0          0      0.7668919
# 5 2711248           0       1072       0          0      0.7560349
# 6 2111692           0          0       0          0      0.7574009

# %%
summary(all_stats$Total.sequencing.reads)
summary(all_stats$Successfully.aligned.reads)
summary(all_stats$libraryyield)
summary(all_stats$captureyield)
summary(all_stats$percaligned)
summary(all_stats$TRB)
summary(all_stats$Reads)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#    95776  2978500  5208360  5821431  6835648 78168018
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#    71989  2274299  4089644  4589625  5381270 59997822
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    12.0   451.7   751.2   994.5  1238.4  8112.0
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#    4.294   74.860  158.270  284.182  337.725 1311.000
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.6187  0.7307  0.7611  0.7804  0.8408  0.9781
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     1.0    45.0   125.5   243.3   351.0  2237.0
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#      10    1103    3316   32559   32723  363060

# %% [markdown]
# ## PCA V usage

# %%
load(file = paste0(datapath, "capTCRseq/int_load_meta.RData"))

# %%
pbmc_pca <- pca_vusage.fx(int_load, pbmc_samples, "PBMC", "FALSE")

# %%
pbmc_pca
# Out:
# plot without title

# %%
pdf(paste0(plotpath, "PBMC_Vusage_PCA.pdf"),
    width = 10, height = 10)
pbmc_pca
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# ## PCA experimental measures

# %%
pca_batch <- pca_batch.fx(int_load, pbmc_samples, "PBMC", "FALSE")
# Out:
# Error in prcomp.default(meta_subset, scale. = TRUE, center = TRUE): cannot rescale a constant/zero column to unit variance
# Traceback:
#
# 1. pca_batch.fx(int_load, pbmc_samples, "PBMC", "FALSE")
# 2. prcomp(meta_subset, scale. = TRUE, center = TRUE)   # at line 16 of file <text>
# 3. prcomp.default(meta_subset, scale. = TRUE, center = TRUE)
# 4. stop("cannot rescale a constant/zero column to unit variance")

# %%
pca_batch
# Out:
# plot without title

# %%
pdf(paste0(plotpath, "PBMC_batch_PCA.pdf"),
    width = 10, height = 10)
pca_batch
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# ## Remove samples

# %%
summary(all_stats$Total.sequencing.reads)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#    95776  2978500  5208360  5821431  6835648 78168018

# %%
summary(all_stats$percaligned)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.6187  0.7307  0.7611  0.7804  0.8408  0.9781

# %%
dim(all_stats)
# Out:
# [1] 272 102

# %%
all_stats[ grepl("372", all_stats$mysample_id), "Total.sequencing.reads"]
# Out:
# [1] 8991539

# %%
head(pbmc_samples,3)
# Out:
#   Shipped DNAextracted DNAused libbatch                           librarypassed
# 1 n = 321  6160        600     190517_M04827_0203_000000000-D6BYT Passed
# 2 n = 321 11200        600     190517_M04827_0203_000000000-D6BYT Passed
# 3 n = 321  3780        600     190517_M04827_0203_000000000-D6BYT Passed
#   Library preparation libraryyield captureyield
# 1 n = 282              825.6       155.42
# 2 n = 282             2006.4       155.42
# 3 n = 282             1161.6       162.64
#   capbatch                           capturepassed Successful capture deepseq
# 1 190624_M04827_0214_000000000-D6F66 Passed        n = 278            Yes
# 2 190624_M04827_0214_000000000-D6F66 Passed        n = 278            Yes
# 3 190624_M04827_0214_000000000-D6F66 Passed        n = 278            Yes
#   Deep sequencing mysample_id TCR TCR analysis Patient Tumor Group
# 1 n = 278         CHP_330_05  No  n = 278      CHP_330 NA    NA
# 2 n = 278         CHP_329_04  No  n = 278      CHP_329 NA    NA
# 3 n = 278         CHP_331_05  No  n = 278      CHP_331 NA    NA

# %%
dim(all_stats)
# Out:
# [1] 272 102

# %%
head(all_stats)
# Out:
#   basename              mysample_id     Shipped DNAextracted DNAused
# 1 CHP_10YO-M_PBMC_DNA   CHP_10YO_M_00   n = 321  4120        600
# 2 CHP_11YO-M_PBMC_DNA   CHP_11YO_M_00   n = 321  4880        600
# 3 CHP_15YO-F-A_PBMC_DNA CHP_15YO_F_A_00 n = 321 18200        600
# 4 CHP_15YO-F-B_PBMC_DNA CHP_15YO_F_B_00 n = 321 35400        600
# 5 CHP_15YO-M_PBMC_DNA   CHP_15YO_M_00   n = 321  7920        600
# 6 CHP_16YO-M_PBMC_DNA   CHP_16YO_M_00   n = 321  3460        600
#   libbatch                           librarypassed Library preparation
# 1 191220_M04827_0327_000000000-D7W4D Passed        n = 282
# 2 191220_M04827_0327_000000000-D7W4D Passed        n = 282
# 3 191220_M04827_0327_000000000-D7W4D Passed        n = 282
# 4 191220_M04827_0327_000000000-D7W4D Passed        n = 282
# 5 191220_M04827_0327_000000000-D7W4D Passed        n = 282
# 6 191220_M04827_0327_000000000-D7W4D Passed        n = 282
#   libraryyield captureyield ... TRA.chains TRB.chains TRD.chains TRG.chains
# 1 1449.6       13.338       ... 2500371    369721      74186     428666
# 2 1948.8        6.232       ... 3481524    550846     116455     489440
# 3 1545.6        7.942       ... 3488717    549330     157638     486162
# 4 1171.2        7.942       ... 5292852    875254     241875     663487
# 5 1843.2        6.232       ... 4275428    660748     130568     632122
# 6 2227.2        4.294       ... 3382456    472114     117300     452204
#   TRA.TRD.chains IGH.chains IGK.chains IGL.chains chains percaligned
# 1 1713555           0        563       0          0      0.7415962
# 2 2318341           0          0       0          0      0.7540386
# 3 1686316        1052          0       0          0      0.7519197
# 4 2991528         793        309       0          0      0.7668919
# 5 2711248           0       1072       0          0      0.7560349
# 6 2111692           0          0       0          0      0.7574009

# %%
pbmc_samples[!pbmc_samples$mysample_id %in% all_stats$mysample_id,]
# Out:
#     Shipped DNAextracted DNAused libbatch
# 34  n = 321 26000.00     600.00  190521_M04827_0204_000000000-D6BKL
# 49  n = 321 11200.00     600.00  190607_M04827_0206_000000000-D6C75
# 58  n = 321  3820.00     600.00  190607_M04827_0206_000000000-D6C75
# 83  n = 321   665.00     600.00  190916_M04827_0264_000000000-D74G2
# 91  n = 321   695.00     600.00  190916_M04827_0264_000000000-D74G2
# 93  n = 321   245.05      38.30  191210_M04827_0319_000000000-D7M28
# 103 n = 321   745.00     600.00  190916_M04827_0264_000000000-D74G2
# 161 n = 321 35600.00     600.00  191104_M04827_0295_000000000-D7FHM
# 162 n = 321 45800.00     600.00  191104_M04827_0295_000000000-D7FHM
# 164 n = 321    77.00      77.00  NA
# 165 n = 321    86.00      86.00  NA
# 166 n = 321   402.00     402.00  NA
# 167 n = 321    85.60      85.60  NA
# 168 n = 321   120.00     120.00  NA
# 169 n = 321   130.00     130.00  NA
# 170 n = 321   292.00     292.00  NA
# 171 n = 321    61.60      61.60  NA
# 172 n = 321   164.00     164.00  NA
# 173 n = 321   104.00     104.00  NA
# 174 n = 321   116.00     116.00  NA
# 176 n = 321   147.00     147.00  NA
# 177 n = 321    49.40      49.40  NA
# 179 n = 321   151.00     151.00  NA
# 180 n = 321   147.00     147.00  NA
# 181 n = 321    28.40      28.40  NA
# 182 n = 321   169.00     169.00  NA
# 183 n = 321   181.00     181.00  NA
# 184 n = 321    98.00      98.00  NA
# 185 n = 321    68.40      68.40  NA
# 186 n = 321   646.00     500.00  NA
# 187 n = 321   132.00     132.00  NA
# 207 n = 321    52.20         NA  200211_M04827_0360_000000000-D87N5
# 223 n = 321   632.00     500.00  191224_M04827_0329_000000000-D7W2Y
# 292 n = 321     0.50       9.83  NA
# 293 n = 321     0.05      11.09  NA
# 294 n = 321    17.00      15.54  NA
# 295 n = 321     0.50      12.35  NA
# 296 n = 321    29.80      27.62  NA
# 297 n = 321     0.05      15.44  NA
# 298 n = 321    18.20      17.09  NA
# 299 n = 321   132.00     125.40  NA
# 300 n = 321    47.40      43.42  NA
# 301 n = 321    60.00      55.74  NA
# 302 n = 321   157.00     145.38  NA
# 303 n = 321    63.60      58.58  NA
# 304 n = 321    50.00      46.00  NA
# 305 n = 321   102.00      97.10  NA
# 306 n = 321     0.05       7.46  NA
# 307 n = 321    91.40      88.11  NA
#     librarypassed Library preparation libraryyield captureyield
# 34  Passed        n = 282             3705.600      21.280
# 49  Passed        n = 282              537.600      84.360
# 58  Passed        n = 282             2697.600      78.660
# 83  Passed        n = 282              196.800       5.852
# 91  Passed        n = 282              600.000       7.334
# 93  Passed        n = 282              552.000     410.400
# 103 Passed        n = 282              950.400      21.090
# 161 Passed        n = 282              662.400     237.500
# 162 Passed        n = 282              389.760     237.500
# 164 Failed        n = 39                41.472       0.000
# 165 Failed        n = 39                62.880       0.000
# 166 Failed        n = 39               262.560       0.000
# 167 Failed        n = 39                75.360       0.000
# 168 Failed        n = 39                81.600       0.000
# 169 Failed        n = 39               696.000       0.000
# 170 Failed        n = 39              1257.600       0.000
# 171 Failed        n = 39                44.736       0.000
# 172 Failed        n = 39               729.600       0.000
# 173 Failed        n = 39                43.680       0.000
# 174 Failed        n = 39               484.800       0.000
# 176 Failed        n = 39               744.000       0.000
# 177 Failed        n = 39                50.880       0.000
# 179 Failed        n = 39               796.800       0.000
# 180 Failed        n = 39               528.000       0.000
# 181 Failed        n = 39                66.720       0.000
# 182 Failed        n = 39               209.280       0.000
# 183 Failed        n = 39               864.000       0.000
# 184 Failed        n = 39               260.160       0.000
# 185 Failed        n = 39               576.000       0.000
# 186 Failed        n = 39               204.480       0.000
# 187 Failed        n = 39               907.200       0.000
# 207 Failed        n = 39                 0.000       0.000
# 223 Passed        n = 282              494.400     323.000
# 292 Failed        n = 39                83.040       0.000
# 293 Failed        n = 39                78.720       0.000
# 294 Failed        n = 39               236.160       0.000
# 295 Failed        n = 39                79.200       0.000
# 296 Failed        n = 39               189.120       0.000
# 297 Failed        n = 39                96.000       0.000
# 298 Failed        n = 39                84.000       0.000
# 299 Failed        n = 39              1113.600       0.000
# 300 Failed        n = 39               188.160       0.000
# 301 Failed        n = 39               537.600       0.000
# 302 Failed        n = 39               364.800       0.000
# 303 Failed        n = 39               210.240       0.000
# 304 Failed        n = 39               206.400       0.000
# 305 Failed        n = 39               389.760       0.000
# 306 Failed        n = 39                62.880       0.000
# 307 Failed        n = 39               988.800       0.000
#     capbatch                           capturepassed Successful capture deepseq
# 34  190531_M00753_0126_000000000-D6D7Y Passed        n = 278            Yes
# 49  D6WFR                              Passed        n = 278            Yes
# 58  D6WFR                              Passed        n = 278            Yes
# 83  NA                                 Failed        n = 4              NA
# 91  NA                                 Failed        n = 4              NA
# 93  201216_M04827_0481_000000000-D9VL2 Passed        n = 278            Yes
# 103 NA                                 Failed        n = 4              NA
# 161 191203_M04827_0315_000000000-D7KC5 Passed        n = 278            Yes
# 162 191203_M04827_0315_000000000-D7KC5 Passed        n = 278            Yes
# 164 NA                                               NA                 NA
# 165 NA                                               NA                 NA
# 166 NA                                               NA                 NA
# 167 NA                                               NA                 NA
# 168 NA                                               NA                 NA
# 169 NA                                               NA                 NA
# 170 NA                                               NA                 NA
# 171 NA                                               NA                 NA
# 172 NA                                               NA                 NA
# 173 NA                                               NA                 NA
# 174 NA                                               NA                 NA
# 176 NA                                               NA                 NA
# 177 NA                                               NA                 NA
# 179 NA                                               NA                 NA
# 180 NA                                               NA                 NA
# 181 NA                                               NA                 NA
# 182 NA                                               NA                 NA
# 183 NA                                               NA                 NA
# 184 NA                                               NA                 NA
# 185 NA                                               NA                 NA
# 186 NA                                               NA                 NA
# 187 NA                                               NA                 NA
# 207 NA                                               NA                 NA
# 223 200123_M00753_0211_000000000-D7YB9 Passed        n = 278            Yes
# 292 NA                                               NA                 NA
# 293 NA                                               NA                 NA
# 294 NA                                               NA                 NA
# 295 NA                                               NA                 NA
# 296 NA                                               NA                 NA
# 297 NA                                               NA                 NA
# 298 NA                                               NA                 NA
# 299 NA                                               NA                 NA
# 300 NA                                               NA                 NA
# 301 NA                                               NA                 NA
# 302 NA                                               NA                 NA
# 303 NA                                               NA                 NA
# 304 NA                                               NA                 NA
# 305 NA                                               NA                 NA
# 306 NA                                               NA                 NA
# 307 NA                                               NA                 NA
#     Deep sequencing mysample_id TCR TCR analysis Patient Tumor Group
# 34  n = 278         CHP_356_04  No  n = 278      CHP_356 NA    NA
# 49  n = 278         CHP_315_05  No  n = 278      CHP_315 NA    NA
# 58  n = 278         CHP_303_05  No  n = 278      CHP_303 NA    NA
# 83  NA              CHP_341_05  No  NA           CHP_341 NA    NA
# 91  NA              CHP_351_05  No  NA           CHP_351 NA    NA
# 93  n = 278         CHP_336_04  No  n = 278      CHP_336 NA    NA
# 103 NA              CHP_339_04  No  NA           CHP_339 NA    NA
# 161 n = 278         CHP_381_04  No  n = 278      CHP_381 NA    NA
# 162 n = 278         CHP_395_01  No  n = 278      CHP_395 NA    NA
# 164 NA              CHP_385_05  No  NA           CHP_385 NA    NA
# 165 NA              CHP_393_01  No  NA           CHP_393 NA    NA
# 166 NA              CHP_398_01  No  NA           CHP_398 NA    NA
# 167 NA              CHP_365_05  No  NA           CHP_365 NA    NA
# 168 NA              CHP_373_05  No  NA           CHP_373 NA    NA
# 169 NA              CHP_401_02  No  NA           CHP_401 NA    NA
# 170 NA              CHP_394_05  No  NA           CHP_394 NA    NA
# 171 NA              CHP_371_05  No  NA           CHP_371 NA    NA
# 172 NA              CHP_381_05  No  NA           CHP_381 NA    NA
# 173 NA              CHP_398_03  No  NA           CHP_398 NA    NA
# 174 NA              CHP_390_01  No  NA           CHP_390 NA    NA
# 176 NA              CHP_378_03  No  NA           CHP_378 NA    NA
# 177 NA              CHP_385_01  No  NA           CHP_385 NA    NA
# 179 NA              CHP_389_01  No  NA           CHP_389 NA    NA
# 180 NA              CHP_364_05  No  NA           CHP_364 NA    NA
# 181 NA              CHP_395_02  No  NA           CHP_395 NA    NA
# 182 NA              CHP_400_02  No  NA           CHP_400 NA    NA
# 183 NA              CHP_389_05  No  NA           CHP_389 NA    NA
# 184 NA              CHP_384_01  No  NA           CHP_384 NA    NA
# 185 NA              CHP_386_03  No  NA           CHP_386 NA    NA
# 186 NA              CHP_391_01  No  NA           CHP_391 NA    NA
# 187 NA              CHP_383_04  No  NA           CHP_383 NA    NA
# 207 NA              CHP_406_02  No  NA           CHP_406 NA    NA
# 223 n = 278         CHP_407_01  No  n = 278      CHP_407 NA    NA
# 292 NA              CHP_403_01  No  NA           CHP_403 NA    NA
# 293 NA              CHP_386_01  No  NA           CHP_386 NA    NA
# 294 NA              CHP_378_05  No  NA           CHP_378 NA    NA
# 295 NA              CHP_367_05  No  NA           CHP_367 NA    NA
# 296 NA              CHP_400_01  No  NA           CHP_400 NA    NA
# 297 NA              CHP_392_03  No  NA           CHP_392 NA    NA
# 298 NA              CHP_380_04  No  NA           CHP_380 NA    NA
# 299 NA              CHP_392_01  No  NA           CHP_392 NA    NA
# 300 NA              CHP_402_01  No  NA           CHP_402 NA    NA
# 301 NA              CHP_388_01  No  NA           CHP_388 NA    NA
# 302 NA              CHP_385_04  No  NA           CHP_385 NA    NA
# 303 NA              CHP_394_02  No  NA           CHP_394 NA    NA
# 304 NA              CHP_375_04  No  NA           CHP_375 NA    NA
# 305 NA              CHP_388_03  No  NA           CHP_388 NA    NA
# 306 NA              CHP_375_03  No  NA           CHP_375 NA    NA
# 307 NA              CHP_367_04  No  NA           CHP_367 NA    NA

# %%
table(pbmc_samples$`TCR analysis`,useNA = "always")
# Out:
# n = 278    <NA>
#     278      43

# %%
# remove 22 samples with < 2mil reads
subset_pbmc <- all_stats[all_stats$Total.sequencing.reads > 2000000,]

# %%
dim(subset_pbmc)
# Out:
# [1] 249 102

# %%
summary(subset_pbmc$DNAused)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     0.0   430.0   600.0   448.5   600.0   600.0

# %%
# one sample is 0 ng added in error in lab processing excel file
## remove 38 samples with < 100 ng input DNA

subset_pbmc <- subset_pbmc[ subset_pbmc$DNAused >= 100,]

# %%
dim(subset_pbmc)
# Out:
# [1] 211 100

# %%
save(subset_pbmc, file = paste0(datapath, "capTCRseq/PBMC_GoodSamples.RData"))

# %%
dim(all)
dim(all_stats)
# Out:
# [1] 272  81
# [1] 272 100

# %% [markdown]
# # cfDNA

# %%
load(file = paste0(gitpath, "data/cfdna_sampleprocessing.RData"))

# %%
load(file = paste0(datapath,"capTCRseq/meta_div_TRB.RData"))

# %%
cfdna_samples$sample_id <- NULL

# %%
all <- merge(cfdna_samples, meta_div[ which(meta_div$sampletype == "cfDNA"),], by.x = "mysample_id", by.y = "sample_id")

# divstats_lst_TRB contains all samples with flow data, remove those without tcr data
all <- all[!is.na(all$basename),]

# %%
dim(all)
# Out:
# [1] 286  82

# %%
stats <- read.csv(file = paste0(datapath, "capTCRseq/align_stats.csv"), header = T)

# %%
stats$basename <- gsub("_barcode.*", "",stats$Input.file.s.)

# %%
all_stats <- merge(all, stats, by = "basename")

# %%
dim(all)
# Out:
# [1] 286  82

# %%
dim(all_stats)
# Out:
# [1] 286 100

# %%
all_stats$percaligned <- all_stats$Successfully.aligned.reads/all_stats$Total.sequencing.reads

# %%
summary(all_stats$percaligned)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.6693  0.8203  0.8660  0.8380  0.8806  0.9278

# %%
summary(all_stats$Total.sequencing.reads)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#    22839  3909173  4880550  5747415  6625276 18558893

# %%
summary(all_stats$Successfully.aligned.reads)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#    20740  3148315  4193616  4877297  5820301 16382810

# %%
p1 <- histdenp(all_stats, "Total.sequencing.reads/1000000", 1)
p2 <- histdenp(all_stats, "Successfully.aligned.reads/1000000", 1)
p3 <- histdenp(all_stats, "percaligned", 0.01)

# %%
p4 <- histdenp(all_stats, "TRB", 5)
p5 <- histdenp(all_stats, "Reads/100", 5)

# %%
p6 <- ggplot(data = all_stats, aes( x = DNAused, y = TRB)) + geom_point() + myplot + myaxis
p7 <- ggplot(data = all_stats, aes( x = libraryyield, y = TRB)) + geom_point() + myplot + myaxis
p8 <- ggplot(data = all_stats, aes( x = captureyield, y = TRB)) + geom_point() + myplot + myaxis

# %%
p9 <- ggplot(data = all_stats, aes( x = Total.sequencing.reads/1000000, y = TRB)) + geom_point() + myplot + myaxis
p10 <- ggplot(data = all_stats, aes( x = Successfully.aligned.reads/1000000, y = TRB)) + geom_point() + myplot + myaxis
p11 <- ggplot(data = all_stats, aes( x = percaligned, y = TRB)) + geom_point() + myplot + myaxis

# %%
p12 <- ggplot(data = all_stats, aes( x = capbatch, y = TRB)) + geom_boxplot() +geom_beeswarm(cex = 0.1)+ myplot + myaxis +
theme( axis.text.x = element_blank())
p13 <- ggplot(data = all_stats, aes( x = libbatch, y = TRB)) + geom_boxplot() +geom_beeswarm(cex = 0.5) + myplot + myaxis +
theme( axis.text.x = element_blank())

# %%
pdf(paste0(plotpath, "QC_cfDNA.pdf"),
    width = 30, height = 30)
plot_grid(p1,p2, p3, p4, p5, p6,p7,p8,p9,p10, p11,p12,p13, ncol = 3)
dev.off()
# Out:
# Warning message:
# “Removed 8 rows containing non-finite values (`stat_bin()`).”
# Warning message:
# “Removed 8 rows containing non-finite values (`stat_density()`).”
# Warning message:
# “Removed 8 rows containing non-finite values (`stat_bin()`).”
# Warning message:
# “Removed 8 rows containing non-finite values (`stat_density()`).”
# Warning message:
# “Removed 8 rows containing missing values (`geom_point()`).”
# Warning message:
# “Removed 8 rows containing missing values (`geom_point()`).”
# Warning message:
# “Removed 9 rows containing missing values (`geom_point()`).”
# Warning message:
# “Removed 8 rows containing missing values (`geom_point()`).”
# Warning message:
# “Removed 8 rows containing missing values (`geom_point()`).”
# Warning message:
# “Removed 8 rows containing missing values (`geom_point()`).”
# Warning message:
# “Removed 8 rows containing non-finite values (`stat_boxplot()`).”
# Warning message:
# “Removed 8 rows containing missing values (`geom_point()`).”
# Warning message:
# “Removed 8 rows containing non-finite values (`stat_boxplot()`).”
# Warning message:
# “Removed 8 rows containing missing values (`geom_point()`).”
# pdf
#   2

# %%
summary(all_stats$Total.sequencing.reads)
summary(all_stats$Successfully.aligned.reads)
summary(all_stats$libraryyield)
summary(all_stats$captureyield)
summary(all_stats$percaligned)
summary(all_stats$TRB)
summary(all_stats$Reads)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#    22839  3909173  4880550  5747415  6625276 18558893
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#    20740  3148315  4193616  4877297  5820301 16382810
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   30.82  200.88  324.48  349.22  456.24 1017.60
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#   104.5   342.0   585.2   628.4   855.0  1641.6       1
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.6693  0.8203  0.8660  0.8380  0.8806  0.9278
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#    1.00    3.00    7.00   13.98   16.00  220.00       8
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#       1     354    2964    6537    7882   88874       8

# %% [markdown]
# ## PCA V usage

# %%
load(file = paste0(gitpath, "data/cfdna_sampleprocessing.RData"))

# %%
load(file = paste0(datapath, "capTCRseq/int_load_meta.RData"))
# Out:
# Warning message in load(file = paste0(datapath, "capTCRseq/int_load_meta.RData")):
# "strings not representable in native encoding will be translated to UTF-8"

# %%
cfdna_pca <- pca_vusage.fx(int_load, cfdna_samples, "cfDNA", "FALSE")
# Out:
# Warning message in eval(e, x, parent.frame()):
# "unable to translate 'Na<U+00EF>ve' to native encoding"
# Warning message in eval(e, x, parent.frame()):
# "unable to translate 'Na<U+00EF>ve.' to native encoding"
# Warning message in eval(e, x, parent.frame()):
# "unable to translate 'Na<U+00EF>ve.TE' to native encoding"

# %%
cfdna_pca
# Out:
# plot without title

# %%
pdf(paste0(plotpath, "cfDNA_Vusage_PCA.pdf"),
    width = 10, height = 10)
cfdna_pca
dev.off()
# Out:
# pdf
#   2

# %%
head(int_load$meta)
# Out:
#   Sample                sample_id       Patient      cycle FOLD ATC Age
# 1 CHP_10YO-M_PBMC_DNA   CHP_10YO_M_00   CHP_10YO_M   X00   NA   NA  NA
# 2 CHP_11YO-M_PBMC_DNA   CHP_11YO_M_00   CHP_11YO_M   X00   NA   NA  NA
# 3 CHP_15YO-F-A_PBMC_DNA CHP_15YO_F_A_00 CHP_15YO_F_A X00   NA   NA  NA
# 4 CHP_15YO-F-B_PBMC_DNA CHP_15YO_F_B_00 CHP_15YO_F_B X00   NA   NA  NA
# 5 CHP_15YO-M_PBMC_DNA   CHP_15YO_M_00   CHP_15YO_M   X00   NA   NA  NA
# 6 CHP_16YO-M_PBMC_DNA   CHP_16YO_M_00   CHP_16YO_M   X00   NA   NA  NA
#   Disease_type TE_fold Pass ... q0_aa q0_v q0_j q0_aav q0_vj q1_aa
# 1 Normal       NA      NA   ... 22    16    8   22     12.0  12.787814
# 2 Normal       NA      NA   ... 21    15   11   21     13.0  14.411620
# 3 Normal       NA      NA   ... 13    12    8   13     10.0  10.930258
# 4 Normal       NA      NA   ...  9     8    7    9      7.5   8.294830
# 5 Normal       NA      NA   ... 33    22   10   33     16.0  29.070103
# 6 Normal       NA      NA   ...  7     6    6    7      6.0   5.495512
#   q1_v      q1_j     q1_aav    q1_vj
# 1  9.563643 5.074581 12.787814  7.319112
# 2 11.695680 8.890122 14.411620 10.292901
# 3  9.683620 6.059679 10.930258  7.871649
# 4  6.692670 6.084720  8.294830  6.388695
# 5 20.127211 7.641330 29.070103 13.884271
# 6  5.434412 4.355165  5.495512  4.894789

# %%
temp <- repFilter(int_load, .method = "by.meta", .query = list(Sample = exclude("CHP_374-05-cfDNA")))
# Out:
# Warning message in eval(e, x, parent.frame()):
# "unable to translate 'Na<U+00EF>ve' to native encoding"
# Warning message in eval(e, x, parent.frame()):
# "unable to translate 'Na<U+00EF>ve.' to native encoding"
# Warning message in eval(e, x, parent.frame()):
# "unable to translate 'Na<U+00EF>ve.TE' to native encoding"

# %%
cfdna_pca <- pca_vusage.fx(temp, cfdna_samples, "cfDNA", "FALSE")
# Out:
# Warning message in eval(e, x, parent.frame()):
# "unable to translate 'Na<U+00EF>ve' to native encoding"
# Warning message in eval(e, x, parent.frame()):
# "unable to translate 'Na<U+00EF>ve.' to native encoding"
# Warning message in eval(e, x, parent.frame()):
# "unable to translate 'Na<U+00EF>ve.TE' to native encoding"

# %%
cfdna_pca
# Out:
# plot without title

# %% [markdown]
# ## PCA experimental measures

# %%
pca_batch <- pca_batch.fx(int_load, cfdna_samples, "cfDNA", "FALSE")
# Out:
# Warning message in eval(e, x, parent.frame()):
# "unable to translate 'Na<U+00EF>ve' to native encoding"
# Warning message in eval(e, x, parent.frame()):
# "unable to translate 'Na<U+00EF>ve.' to native encoding"
# Warning message in eval(e, x, parent.frame()):
# "unable to translate 'Na<U+00EF>ve.TE' to native encoding"

# %%
pca_batch
# Out:
# plot without title

# %%
pdf(paste0(plotpath, "cfDNA_batch_PCA.pdf"),
    width = 10, height = 10)
pca_batch
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# ## Remove samples

# %%
summary(all_stats$Total.sequencing.reads)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#    22839  3909173  4880550  5747415  6625276 18558893

# %%
summary(all_stats$percaligned)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.6693  0.8203  0.8660  0.8380  0.8806  0.9278

# %%
# remove 7 samples with < 2mil reads
subset_cfdna <- all_stats[all_stats$Total.sequencing.reads > 2000000,]

# %%
dim(subset_cfdna)
# Out:
# [1] 279 101

# %%
# remove the outlier from V usage, CHP_374-05-cfDNA It is an EWS case with one TRB and 3 reads.

# %%
subset_cfdna <- subset_cfdna[!grepl("CHP_374-05-cfDNA", subset_cfdna$basename),]

# %%
dim(subset_cfdna)
# Out:
# [1] 278 101

# %%
colnames(subset_cfdna)
# Out:
#   [1] "basename"
#   [2] "mysample_id"
#   [3] "DNA samples"
#   [4] "DNAextracted"
#   [5] "DNAused"
#   [6] "librarypassed"
#   [7] "libbatch"
#   [8] "Library preparation"
#   [9] "libraryyield"
#  [10] "DNAforcapture"
#  [11] "captureyield"
#  [12] "capbatch"
#  [13] "capturepassed"
#  [14] "Successful capture"
#  [15] "deepseq"
#  [16] "Deep sequencing"
#  [17] "TCR"
#  [18] "TCR analysis"
#  [19] "Patient.x"
#  [20] "Tumor"
#  [21] "Group.x"
#  [22] "Patient.y"
#  [23] "cycle"
#  [24] "FOLD"
#  [25] "ATC"
#  [26] "Age"
#  [27] "Disease_type"
#  [28] "TE_fold"
#  [29] "CD3"
#  [30] "EM"
#  [31] "CM"
#  [32] "Naïve"
#  [33] "SCM"
#  [34] "TE"
#  [35] "EM%"
#  [36] "CM%"
#  [37] "Naïve%"
#  [38] "SCM%"
#  [39] "TE%"
#  [40] "Naïve/TE"
#  [41] "N+CM+SCM/TE+EM"
#  [42] "PD-1"
#  [43] "PDL1"
#  [44] "LAG3"
#  [45] "TIM3"
#  [46] "CTLA4"
#  [47] "PD1%"
#  [48] "PDL1%"
#  [49] "LAG3%"
#  [50] "TIM3%"
#  [51] "CTLA4%"
#  [52] "Any NCR"
#  [53] "PD1 + LAG3 + TIM3"
#  [54] "cancergroup"
#  [55] "agegroup"
#  [56] "foldgroup"
#  [57] "Remission"
#  [58] "Relapse"
#  [59] "Transplant"
#  [60] "CART"
#  [61] "TRB"
#  [62] "Reads"
#  [63] "CPKR"
#  [64] "Average_reads"
#  [65] "VMR"
#  [66] "Max_reads"
#  [67] "Singletons"
#  [68] "Doubletons"
#  [69] "qD"
#  [70] "Sample_Coverage"
#  [71] "observed_Richness"
#  [72] "estimated_Richness"
#  [73] "SE_Richeness"
#  [74] "observed_Shannon"
#  [75] "estimated_Shannon"
#  [76] "SE_Shannon"
#  [77] "observed_Simpson"
#  [78] "estimated_Simpson"
#  [79] "SE_Simpson"
#  [80] "file"
#  [81] "Group.y"
#  [82] "sampletype"
#  [83] "Input.file.s."
#  [84] "Output.file.s."
#  [85] "Version"
#  [86] "Total.sequencing.reads"
#  [87] "Successfully.aligned.reads"
#  [88] "Alignment.failed..no.hits..not.TCR.IG.."
#  [89] "Alignment.failed.because.of.absence.of.CDR3.parts"
#  [90] "Alignment.failed.because.of.low.total.score"
#  [91] "Alignment.aided.overlaps"
#  [92] "TRA.chains"
#  [93] "TRB.chains"
#  [94] "TRD.chains"
#  [95] "TRG.chains"
#  [96] "TRA.TRD.chains"
#  [97] "IGH.chains"
#  [98] "IGK.chains"
#  [99] "IGL.chains"
# [100] "chains"
# [101] "percaligned"

# %%
summary(subset_cfdna$DNAused)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   3.002  14.362  20.000  17.186  20.000  20.000

# %%
subset_cfdna[ subset_cfdna$DNAused < 5, ]
# Out:
#     basename         mysample_id DNA samples DNAextracted DNAused librarypassed
# 103 CHP_365-05_cfDNA CHP_365_05  n = 316     0.6          4.956   Passed
# 143 CHP_378-03_cfDNA CHP_378_03  n = 316     0.4          4.928   Passed
# 193 CHP_391-04_cfDNA CHP_391_04  n = 316     0.4          3.002   Passed
# 281 CHP_419-01_cfDNA CHP_419_01  n = 316     0.4          4.730   Passed
#     libbatch                           Library preparation libraryyield
# 103 200604_M04827_0388_000000000-D8756 n = 316              73.44
# 143 200604_M04827_0388_000000000-D8756 n = 316             128.64
# 193 200604_M04827_0388_000000000-D8756 n = 316              84.96
# 281 200604_M04827_0388_000000000-D8756 n = 316             121.92
#     DNAforcapture ... TRA.chains TRB.chains TRD.chains TRG.chains
# 103  73.44        ... 1184597    130589     32676      185880
# 143 128.64        ... 2101815    242297     80375      168265
# 193  84.96        ... 1996636    236779     72417      220362
# 281 121.92        ... 2790707    290355     89882      367018
#     TRA.TRD.chains IGH.chains IGK.chains IGL.chains chains percaligned
# 103 1580458          0          0        0          0      0.8895689
# 143 2795981        120          0        0          0      0.8684310
# 193 3116877          0          0        0          0      0.8882489
# 281 4388924          0        163        0          0      0.8799967

# %%
subset_cfdna <- subset_cfdna[ subset_cfdna$DNAused >= 5, ]

# %%
dim(subset_cfdna)
# Out:
# [1] 274 101

# %%
save(subset_cfdna, file = paste0(datapath, "capTCRseq/cfDNA_GoodSamples.RData"))
